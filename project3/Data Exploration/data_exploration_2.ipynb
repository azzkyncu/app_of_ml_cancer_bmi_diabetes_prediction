# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('./Resources/behavioral_revised_data_final.csv')
data.head()
# Out:
#      State State Code     Sex Marital Status    Age        Race     Education  \
# 0  Alabama         AL  Female        Widowed  70-74  White only   High School
# 1  Alabama         AL    Male        Married    >80  White only  College 4yrs
# 2  Alabama         AL    Male        Married  50-54  White only  College 3yrs
# 3  Alabama         AL    Male        Married  35-39  White only  College 3yrs
# 4  Alabama         AL    Male        Married  65-69  White only  College 4yrs
#
#    Weight(lbs)  Height(ft)       Income  ...  Physical Activity/Day(mints)  \
# 0        128.0     4.99980  20000-25000  ...                          30.0
# 1        172.0     5.83310       >75000  ...                          40.0
# 2        135.0     5.33312  35000-50000  ...                         308.0
# 3        190.0     5.99976  15000-20000  ...                          20.0
# 4        212.0     5.91643      Refused  ...                         150.0
#
# ...

# %%
len(data)
# Out:
# 55729

# %%
data.columns
# Out:
# Index(['State', 'State Code', 'Sex', 'Marital Status', 'Age', 'Race',
#        'Education', 'Weight(lbs)', 'Height(ft)', 'Income', 'Vegetables/Day',
#        'Fruits/Day', 'Physical Activity/Day(mints)', 'Smoking', 'Alcohol/Day',
#        'BMI', 'Blood Pressure', 'Cholestrol', 'Heart Disease', 'Stroke',
#        'Cancer', 'Diabetes'],
#       dtype='object')

# %%
#renaming the columns 
data.columns = ['state', 'state_code', 'sex', 'marital_status', 'age', 'race',
       'education', 'weight', 'height', 'income', 'vegetables_day',
       'fruits_day', 'physical_ctivity', 'smoking', 'alcohol_day',
       'bmi', 'blood_pressure', 'cholestrol', 'heart_disease', 'stroke',
       'cancer', 'diabetes']

# %%
data.head()
# Out:
#      state state_code     sex marital_status    age        race     education  \
# 0  Alabama         AL  Female        Widowed  70-74  White only   High School
# 1  Alabama         AL    Male        Married    >80  White only  College 4yrs
# 2  Alabama         AL    Male        Married  50-54  White only  College 3yrs
# 3  Alabama         AL    Male        Married  35-39  White only  College 3yrs
# 4  Alabama         AL    Male        Married  65-69  White only  College 4yrs
#
#    weight   height       income  ...  physical_ctivity     smoking  \
# 0   128.0  4.99980  20000-25000  ...              30.0   Every day
# 1   172.0  5.83310       >75000  ...              40.0  Not at all
# 2   135.0  5.33312  35000-50000  ...             308.0   Every day
# 3   190.0  5.99976  15000-20000  ...              20.0   Every day
# 4   212.0  5.91643      Refused  ...             150.0  Not at all
#
#    alcohol_day            bmi  blood_pressure cholestrol heart_disease stroke  \
# ...

# %%
data.dropna(axis='columns')
# Out:
#              state state_code     sex                   marital_status    age  \
# 0          Alabama         AL  Female                          Widowed  70-74
# 1          Alabama         AL    Male                          Married    >80
# 2          Alabama         AL    Male                          Married  50-54
# 3          Alabama         AL    Male                          Married  35-39
# 4          Alabama         AL    Male                          Married  65-69
# 5          Alabama         AL  Female                    Never married  55-59
# 6          Alabama         AL    Male                         Divorced  65-69
# 7          Alabama         AL  Female                    Never married  50-54
# 8          Alabama         AL    Male                         Divorced  70-74
# 9          Alabama         AL    Male                          Married  55-59
# 10         Alabama         AL    Male                          Married  75-79
# ...

# %%
# dropping 'refused' and ''Don´t Know/Not Sure' from all rows. 
data =data[data.marital_status != 'Refused']
data =data[data.marital_status != 'Don´t Know/Not Sure']
data =data[data.age != 'Refused']
data =data[data.age != 'Don´t Know/Not Sure']
data =data[data.race != 'Refused']
data =data[data.race != 'Don´t Know/Not Sure']
data =data[data.education != 'Refused']
data =data[data.education != 'Don´t Know/Not Sure']
data =data[data.weight != 'Refused']
data =data[data.weight != 'Don´t Know/Not Sure']
data =data[data.height != 'Refused']
data =data[data.height != 'Don´t Know/Not Sure']
data =data[data.income != 'Refused']
data =data[data.income != 'Don´t Know/Not Sure']
data =data[data.physical_ctivity != 'Refused']
data =data[data.physical_ctivity != 'Don´t Know/Not Sure']
data =data[data.smoking != 'Refused']
data =data[data.smoking != 'Don´t Know/Not Sure']
data =data[data.alcohol_day != 'Refused']
data =data[data.alcohol_day != 'Don´t Know/Not Sure']
data =data[data.bmi != 'Refused']
data =data[data.bmi != 'Don´t Know/Not Sure']
data =data[data.blood_pressure != 'Refused']
data =data[data.blood_pressure != 'Don´t Know/Not Sure']
data =data[data.cholestrol != 'Refused']
data =data[data.cholestrol != 'Don´t Know/Not Sure']
data =data[data.heart_disease != 'Refused']
data =data[data.heart_disease != 'Don´t Know/Not Sure']
data =data[data.stroke != 'Refused']
data =data[data.stroke != 'Don´t Know/Not Sure']
data =data[data.cancer != 'Refused']
data =data[data.cancer != 'Don´t Know/Not Sure']
data =data[data.diabetes != 'Refused']
data =data[data.diabetes != 'Don´t Know/Not Sure']
data =data[data.income != 'Refused']
data =data[data.income != 'Don´t Know/Not Sure']
data =data[data.income != 'Don’t know/Not sure']
data =data[data.income != 'Don’t know/Not sure']
# Out:
# /Users/azizkoyuncu/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
data.head()
# Out:
#      state state_code     sex marital_status    age        race     education  \
# 0  Alabama         AL  Female        Widowed  70-74  White only   High School
# 1  Alabama         AL    Male        Married    >80  White only  College 4yrs
# 2  Alabama         AL    Male        Married  50-54  White only  College 3yrs
# 3  Alabama         AL    Male        Married  35-39  White only  College 3yrs
# 5  Alabama         AL  Female  Never married  55-59  Black only  College 4yrs
#
#    weight   height       income  ...  physical_ctivity     smoking  \
# 0   128.0  4.99980  20000-25000  ...              30.0   Every day
# 1   172.0  5.83310       >75000  ...              40.0  Not at all
# 2   135.0  5.33312  35000-50000  ...             308.0   Every day
# 3   190.0  5.99976  15000-20000  ...              20.0   Every day
# 5   130.0  5.49978  15000-20000  ...              30.0   Every day
#
#    alcohol_day            bmi  blood_pressure cholestrol heart_disease stroke  \
# ...

# %%
X = data[["sex", "alcohol_day", "physical_ctivity"]].copy()
y = data["weight"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (50104, 3) (50104, 1)

# %%
import seaborn as sns
cordata = data[["sex","alcohol_day","physical_ctivity", "weight", "age"]].copy()
#cordata = cordata[cordata["physical_ctivity"]<200]
#cordata = cordata[cordata["age"]=="40-44"]
#cordata = cordata[cordata["sex"]=="Female"]
#cordata = cordata[cordata["weight"]<400]
g = sns.pairplot(cordata)

# %%
g = sns.scatterplot(cordata["physical_ctivity"],cordata["weight"])

# %%
sns.jointplot(x=cordata["physical_ctivity"], y=cordata["weight"], kind="hex", color="k");

# %%
sns.jointplot(x=cordata["alcohol_day"], y=cordata["weight"], kind="hex", color="k");

# %%
cordata.corr()
# Out:
#                   alcohol_day  physical_ctivity    weight
# alcohol_day          1.000000         -0.017022  0.130254
# physical_ctivity    -0.017022          1.000000 -0.043408
# weight               0.130254         -0.043408  1.000000

# %%
sns.heatmap(cordata.corr());

# %%
#sns.barplot(cordata["age"],cordata["weight"])

corgroup = cordata.groupby(by='age')
corgroup['weight'].mean()
# Out:
# age
# 18-24    179.028909
# 25-29    183.197133
# 30-34    187.839022
# 35-39    187.287317
# 40-44    186.676089
# 45-49    184.978536
# 50-54    180.557724
# 55-59    180.176890
# 60-64    181.306295
# 65-69    181.378963
# 70-74    177.461275
# 75-79    173.391546
# >80      164.226415
# Name: weight, dtype: float64

# %%
corgroup['weight'].count()
# Out:
# age
# 18-24     761
# 25-29    1395
# 30-34    2373
# 35-39    2941
# 40-44    3007
# 45-49    3401
# 50-54    4868
# 55-59    6032
# 60-64    6608
# 65-69    7254
# 70-74    5255
# 75-79    3241
# >80      2968
# Name: weight, dtype: int64

# %%
corgroup['weight'].mean().plot.bar()

# %%
cordata.boxplot("weight",by="age")

# %%
cordata["activity_level"] = "0 - Not active"
cordata.loc[cordata["physical_ctivity"]>30,"activity_level"] = "1 - Moderate"
cordata.loc[cordata["physical_ctivity"]>60,"activity_level"] = "2 - Active"
cordata["activity_level"].value_counts()

cordata.boxplot("weight",by="activity_level")

# %%
data = X.copy()

data_binary_encoded = pd.get_dummies(data, columns=["sex"], drop_first=True)
data_binary_encoded.head()
# Out:
#    alcohol_day  physical_ctivity  sex_Male
# 0          2.0              30.0         0
# 1          1.0              40.0         1
# 2          1.0             308.0         1
# 3          1.0              20.0         1
# 5          1.0              30.0         0

# %%
from sklearn.model_selection import train_test_split

X = pd.get_dummies(X, drop_first=True)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

X_train.head()
# Out:
#        alcohol_day  physical_ctivity  sex_Male
# 12549          2.0         16.857143         1
# 34929          2.0          8.571429         0
# 44225          1.0        111.000000         0
# 542            2.0          8.571429         1
# 55160          2.0         46.000000         1

# %%
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)
# Out:
# /Users/azizkoyuncu/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)

# %%
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)
# Out:
# /Users/azizkoyuncu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.
#   """Entry point for launching an IPython kernel.
# /Users/azizkoyuncu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DataConversionWarning: Data with input dtype uint8, float64 were all converted to float64 by StandardScaler.

# %%
fig1 = plt.figure(figsize=(12, 6))
axes1 = fig1.add_subplot(1, 2, 1)
axes2 = fig1.add_subplot(1, 2, 2)

axes1.set_title("Original Data")
axes2.set_title("Scaled Data")

maxx = X_train["weight"].max()
maxy = y_train.max()
axes1.set_xlim(-maxx + 1, maxx + 1)
axes1.set_ylim(-maxy + 1, maxy + 1)

axes2.set_xlim(-2, 2)
axes2.set_ylim(-2, 2)

def set_axes(ax):
    ax.spines['left'].set_position('center')
    ax.spines['right'].set_color('none')
    ax.spines['bottom'].set_position('center')
    ax.spines['top'].set_color('none')
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')
    
set_axes(axes1)
set_axes(axes2)

axes1.scatter(X_train["weight"], y_train)
axes2.scatter(X_train_scaled[:,0], y_train_scaled[:])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'weight'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-d6411d577b0c> in <module>
#       6 axes2.set_title("Scaled Data")
# ...
